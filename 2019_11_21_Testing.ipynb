# %%
import flirimageextractor
from matplotlib import cm
from matplotlib import pyplot as plt
import numpy as np

# %%
img = plt.imread('C:\\Users\\susanmeerdink\\Documents\\Git\\FLIR8786_Copy.jpg')

# %%
plt.figure()
plt.imshow(img)
plt.show()

# %%
flir = flirimageextractor.FlirImageExtractor(palettes=[cm.jet, cm.bwr, cm.gist_ncar],exiftool_path="C:\\Users\\susanmeerdink\\.utilities\\exiftool.exe")
flir.process_image('C:\\Users\\susanmeerdink\\Dropbox (UFL)\\Analysis\\Thermal Experiment\\Soledad\\IR_55920_Copy.jpg', RGB=True)
flir.plot()

# %%
data = flir.extract_thermal_image()
np.savetxt('C:\\Users\\susanmeerdink\\Dropbox (UFL)\\Analysis\\Thermal Experiment\\Soledad\\IR_55920_Copy.csv', data, delimiter=',')
